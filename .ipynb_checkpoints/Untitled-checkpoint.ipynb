# %%
import torch
import torch.nn as nn
import torch.autograd
import numpy as np
from PIL import Image
import gdal
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torch.nn.functional as F
import torch.utils.data as data
from torch.nn.modules.loss import _Loss
from torch.autograd import Function, Variable

# %%
#### cvt2tensor = transforms.ToTensor()
cvt2pil = transforms.ToPILImage()

class Spacenet_Dataset(data.Dataset):
    def __init__(self, annotationsFile,train = True, transform=None, target_transform = None):
        files = open(annotationsFile,'r')
        self.transform=transform
        self.target_transform=target_transform
        items=[]
        #print(lines[0].split('\n'))
        for line in files:
            #print(line)
            imp,_ = line.split('\n')
            ip,out = imp.split(' ')
            ip = ip
            out = out[:-4]+'segcls.png'
            
            item = [ip,out]
            items.append(item)
        self.data = items
        self.inp_img_paths=[]
        self.out_img_paths=[]
        for dat in self.data:
            self.inp_img_paths.append(dat[0])
            self.out_img_paths.append(dat[1])
        #print(len(inp_img_paths))
              
    def getImage(self,path):
        pil_image = Image.open(path)
        pil_image = pil_image.convert('RGB')
        return pil_image

    def getImage_out(self,path):
        pil_image = Image.open(path)
        pil_image = pil_image.convert('L')
        image_ar = np.where(np.asarray(pil_image) != 0, 1, 0)
        return image_ar
    
    def __getitem__(self, index):
        cur_in_path = self.inp_img_paths[index]
        cur_out_path = self.out_img_paths[index]
        in_image = self.getImage(cur_in_path)
        out_image = self.getImage_out(cur_out_path)
        
        if self.transform is not None:
            in_image = self.transform(in_image)
            out_image = self.transform(out_image.reshape(650,650,1))
        return in_image, out_image
    
    def __len__(self):
        return len(self.inp_img_paths)

imgTransform = transforms.Compose([transforms.ToTensor()])

trainData = Spacenet_Dataset("/home/shriragk/project/AOI_3_Paris_Train/annotations/trainval.txt",transform=imgTransform)
valData = Spacenet_Dataset("/home/shriragk/project/AOI_3_Paris_Train/annotations/test.txt",transform=imgTransform)
#inp,out = trainData[0]
#print(inp.size())
#print(out.shape)

# %%
class MyNet(nn.Module):
    def __init__(self):
        super(MyNet, self).__init__()
        # Convolutional layers.
        
        self.conv1 = nn.Conv2d(3, 8, 8, padding = 1)
        self.conv2 = nn.Conv2d(8, 16, 6)
        self.conv3 = nn.Conv2d(16, 32, 7)
        self.conv4 = nn.Conv2d(32, 64, 3)
        self.conv5 = nn.Conv2d(64, 128, 3)
        self.conv6 = nn.Conv2d(128, 256, 3)
        self.conv7 = nn.Conv2d(256, 512, 3)
        
        self.deconv1 = nn.ConvTranspose2d(512,256,3)
        self.deconv2 = nn.ConvTranspose2d(256,128,3)
        self.deconv3 = nn.ConvTranspose2d(128,64,3)
        self.deconv4 = nn.ConvTranspose2d(64,32,3)
        self.deconv5 = nn.ConvTranspose2d(32,16,7)
        self.deconv6 = nn.ConvTranspose2d(16,8,6)
        self.deconv7 = nn.ConvTranspose2d(8,1,8, padding = 1)
        
        self.Norm_1 = nn.BatchNorm2d(8)
        self.Norm_2 = nn.BatchNorm2d(16)
        self.Norm_3 = nn.BatchNorm2d(32) 
        self.Norm_4 = nn.BatchNorm2d(64) 
        self.Norm_5 = nn.BatchNorm2d(128) 
        self.Norm_6 = nn.BatchNorm2d(256) 
        self.Norm_7 = nn.BatchNorm2d(512)
        self.Norm_9 = nn.BatchNorm2d(256)
        self.Norm_10 = nn.BatchNorm2d(128)
        self.Norm_11 = nn.BatchNorm2d(64)
        self.Norm_12 = nn.BatchNorm2d(32)
        self.Norm_13 = nn.BatchNorm2d(16)
        self.Norm_14 = nn.BatchNorm2d(8)
        
        
        self.pool2 = nn.MaxPool2d(2,return_indices=False)
        #self.pool3 = nn.MaxPool2d(3,return_indices=False)
        
        self.upsample2 = nn.Upsample(scale_factor = 2)
        #self.upsample3 = nn.Upsample(scale_factor = 3)
        #self.upsample2 = nn.Upsample(size = (256, 98, 98))
        #self.upsample4 = nn.Upsample()
        #self.upsample6 = nn.Upsample()
        
        #self.sigmoid = nn.Sigmoid()
        self.elu = nn.ELU()
        
    def forward(self, x):
        
        outc1 = self.elu(self.conv1(x))
        outc1 = self.Norm_1(outc1)
        
        outc2 = self.elu(self.conv2(outc1))
        outc2 = self.Norm_2(outc2)
        outc3 = self.pool2(outc2)
        
        outc3 = self.elu(self.conv3(outc3))
        outc3 = self.Norm_3(outc3)
        
        outc4 = self.elu(self.conv4(outc3))
        outc4 = self.Norm_4(outc4)
        outc5 = self.pool2(outc4)
        
        outc5 = self.elu(self.conv5(outc5))
        outc5 = self.Norm_5(outc5)
        
        outc6 = self.elu(self.conv6(outc5))
        outc6 = self.Norm_6(outc6)
        outc7 = self.pool2(outc6)
        
        outc7 = self.elu(self.conv7(outc7))
        outc7 = self.Norm_7(outc7)
        
        outd1 = self.elu(self.deconv1(outc7))
        outd1 = self.Norm_9(outd1)
        outd2 = self.upsample2(outd1)
        
        outd2 = outd2 + outc6
        outd2 = self.elu(self.deconv2(outd2))
        outd3 = self.Norm_10(outd2)
        
        outd3 = outd3 + outc5
        outd3 = self.elu(self.deconv3(outd2))
        outd4 = self.Norm_11(outd3)
        
        outd4 = self.upsample2(outd4)
        outd4 = outd4 + outc4 
        outd4 = self.elu(self.deconv4(outd4))
        outd5 = self.Norm_12(outd4)
        
        outd5 = outd5 + outc3 
        outd5 = self.elu(self.deconv5(outd5))
       
        outd6 = self.upsample2(outd5)
        outd6 = self.Norm_13(outd6)
        
        outd6 = outd6 + outc2 
        outd6 = self.elu(self.deconv6(outd6))
        outd7 = self.Norm_14(outd6)
        
        outd7 = outd7 + outc1 
        outd7 = self.elu(self.deconv7(outd7))
        
        
        return outd7
        #return self.sigmoid(outd7)

# %%
import random

def get_sample(model):
    inp,out = valData[random.randint(0,100)] # change it to Valdata if necessary, dont forget to change value inside rand()
    inp = inp.view(-1,3,650,650)
    sample_ip = torch.autograd.Variable(inp)
    sample_out = model(sample_ip)
    #print(sample_out.size())
    sample_out = sample_out.view(-1,sample_out.size(2),sample_out.size(3)) * 255
    sample_out = cvt2pil(sample_out.data.cpu()).convert('RGB')
    sample_inp = cvt2pil(inp.view(-1,650,650)) 
    #print(out.shape)
    plt.imshow(sample_inp)
    plt.show()
    plt.imshow(sample_out)
    plt.show()
    plt.imshow(cvt2pil(out.view(-1,650,650) * 255).convert('RGB') )
    plt.show()
    return (sample_out, sample_inp, out)
    
model = MyNet()
#modelS = StanfordNet()
get_sample(model)
# Out:
# (<PIL.Image.Image image mode=RGB size=650x650 at 0x7F80EB63EF10>,
#  <PIL.Image.Image image mode=RGB size=650x650 at 0x7F80EB63EF90>,
#
#  ( 0 ,.,.) =
#  1.00000e-03 *
#    0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#    0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#    0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#             ...             ⋱             ...
#    0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#    0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#    0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#  [torch.FloatTensor of size 1x650x650])

# %%
imgTransform = transforms.Compose([transforms.ToTensor()])


trainData = Spacenet_Dataset("/home/shriragk/project/AOI_3_Paris_Train/annotations/trainval.txt",
                             transform=imgTransform)
valData = Spacenet_Dataset("/home/shriragk/project/AOI_3_Paris_Train/annotations/test.txt",
                           transform=imgTransform)

trainLoader = torch.utils.data.DataLoader(trainData, batch_size = 8, 
                                          shuffle = True, num_workers = 16)
valLoader = torch.utils.data.DataLoader(valData, batch_size = 8, 
                                        shuffle = False, num_workers = 16)

# %%
for param in model.parameters():
    print(torch.mean(param))
# Out:
# Variable containing:
# 1.00000e-03 *
#  -1.9090
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-02 *
#   1.0902
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-04 *
#   6.1138
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#  -2.1261
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-05 *
#   4.2412
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#  -3.4172
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-04 *
#  -1.8758
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   1.9057
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-04 *
#   1.1076
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#  -1.2768
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-06 *
#  -8.5337
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   1.0885
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-06 *
#   2.0576
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-04 *
#   4.7476
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-06 *
#   8.2189
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-04 *
#  -3.5673
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-05 *
#   1.8853
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-04 *
#   1.6204
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-05 *
#  -1.5368
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-04 *
#   3.2931
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-06 *
#  -5.9170
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   1.0826
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-05 *
#  -1.3658
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-05 *
#   1.1296
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-05 *
#   7.7371
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-02 *
#  -1.0057
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#  -1.3101
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-02 *
#  -2.6692
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.4039
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.4716
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.5016
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.5540
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.5613
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.5046
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.5112
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.5001
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.4584
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.4493
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.4943
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.3887
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0.3224
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  0
# [torch.FloatTensor of size 1]

# %%
from tqdm import tqdm as tqdm

train_loss=[]
test_loss=[]

def train_rnn_model(model, criterion, optimizer, trainData, valData, n_epochs = 10, use_gpu = False):      
   
    if use_gpu:
        model = model.cuda()
        criterion = criterion.cuda()
        
    # Training loop.
    for epoch in range(0, n_epochs):
        cum_loss = 0.0
        accuracy = 0
        # Make a pass over the training data.
        t = tqdm(trainData, desc = 'Training epoch %d' % epoch)
        model.train()  # This is important to call before training!
        for (i,(ip_image, out_image)) in enumerate(t): 
       
            input_image = torch.autograd.Variable(ip_image)
            target = torch.autograd.Variable(out_image)

            if use_gpu:
                input_image = input_image.cuda()
                target = target.cuda()
            y_ = model(input_image)
            loss_overall = criterion(y_, target)
            y_ = y_ * target
            

            optimizer.zero_grad()
            loss_mask = criterion(y_, target)
            loss = loss_mask + loss_overall
            cum_loss += loss.data[0]

            loss.backward()
            # Weight and bias updates.
            optimizer.step()                

            # logging information.
            t.set_postfix(loss = cum_loss / (1 + i)) 

        train_loss.append(cum_loss/(i+1))


        # Make a pass over the validation data.
        cum_loss = 0.0
        accuracy = 0
        
        t = tqdm(valData, desc = 'Validation epoch %d' % epoch)
        model.eval()  # This is important to call before evaluating!
        for (i,(ip_image,out_image)) in enumerate(t): 
        
            input_image = torch.autograd.Variable(ip_image)
            target = torch.autograd.Variable(out_image)

            if use_gpu:
                input_image = input_image.cuda()
                target = target.cuda()
                
     
            y_ = model(input_image)
            loss_overall = criterion(y_, target)
            y_ = y_ * target
            
            loss_mask = criterion(y_, target)
            loss = loss_mask + loss_overall
            
            cum_loss += loss.data[0]
            
            t.set_postfix(loss = cum_loss / (1+i))
            
        test_loss.append(cum_loss/(i+1))
    return model

model = MyNet()

criterion = nn.BCEWithLogitsLoss()
#criterion = nn.SmoothL1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr = 5e-2)


# Train the previously defined model.
trained_model = train_rnn_model(nn.DataParallel(model),criterion, optimizer, trainLoader,
                                valLoader, n_epochs = 3, use_gpu = True)
# Out:
# Training epoch 0: 100%|██████████| 115/115 [02:29<00:00,  1.30s/it, loss=1.08]
# Validation epoch 0: 100%|██████████| 29/29 [00:12<00:00,  2.30it/s, loss=1.01]
# Training epoch 1: 100%|██████████| 115/115 [02:18<00:00,  1.20s/it, loss=1.01]
# Validation epoch 1: 100%|██████████| 29/29 [00:12<00:00,  2.36it/s, loss=1.01]
# Training epoch 2: 100%|██████████| 115/115 [02:18<00:00,  1.21s/it, loss=1.01]
# Validation epoch 2: 100%|██████████| 29/29 [00:12<00:00,  2.34it/s, loss=1.01]

# %%
sample_out, sample_inp, out = get_sample(trained_model)

# %%
plt.plot(test_loss)
plt.show()

# %%
'''for param in model.parameters():
    print(param.mean().data)
'''
model = MyNet()
param_means = [param.mean().data.cpu().numpy() for param in model.parameters()]
plt.plot(param_means)
plt.show()

# %%
param_means = [param.mean().data.cpu().numpy() for param in trained_model.parameters()]
plt.plot(param_means)
plt.show()

# %%
x = torch.F([[1,2,3],[1,2,3]])
x = x.type('torch.LongTensor')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0dc22edece4d> in <module>()
# ----> 1 x = torch.F([[1,2,3],[1,2,3]])
#       2 x = x.type('torch.LongTensor')
#
# AttributeError: 'module' object has no attribute 'F'

# %%
criterion = nn.BCEWithLogitsLoss()
a = torch.FloatTensor([[[[1,2,3],[1,2,3]]]])
x = torch.FloatTensor([[[[1,0,1],[1,0,0]]]])
print(a)
print(x)
print(a*x)

# %%
x = np.array([1,2,3])
print(x.shape)
x = x.reshape(3,1)
print(x.shape)
x

# %%
model = MyNet()

# %%
for param in model.parameters():
    print(torch.mean(param))
